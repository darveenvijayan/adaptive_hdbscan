# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.cluster as cluster
import sklearn.datasets as datasets
import time
# %matplotlib inline
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.25, 's' : 80, 'linewidths':0}


import timeit
import time
import numpy as np
import hdbscan
import sklearn.datasets as datasets
import resource

# %% [markdown]
# # A

# %%
data = np.load('clusterable_data.npy')
data.shape
# Out:
# (2309, 2)

# %%
plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # B

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[(0,0)], cluster_std=1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # C

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (1,0),
    (1,1),
    (0,1)
], cluster_std=0.1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # D

# %%
data1, _ = datasets.make_blobs(n_samples=500, centers=[(0,0)], cluster_std=0.8)
data2, _ = datasets.make_blobs(n_samples=500, centers=[(4,0)], cluster_std=0.6)
data3, _ = datasets.make_blobs(n_samples=500, centers=[(4,4)], cluster_std=0.4)
data4, _ = datasets.make_blobs(n_samples=500, centers=[(0,4)], cluster_std=0.2)


data = np.vstack([data1,data2,data3,data4])

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()

# %% [markdown]
# # E

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (1,0),
    (2,0),
    (3,0)
], cluster_std=0.1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # F

# %%
data, _ = datasets.make_moons(n_samples=2000, noise=0.15)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()

# %% [markdown]
# # Other Datasets

# %% [markdown]
# * Random
# * Small clusters
# * large clusters
# * cluster with shapes
# * cluster with different densities
# * Noise

# %% [markdown]
# ## 1. Random

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[(0,0)], cluster_std=1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # 2. Multiple circular clusters of same density

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (1,0),
    (1,1),
    (0,1)
], cluster_std=0.1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # 2. Multiple circular clusters of different density

# %%
data1, _ = datasets.make_blobs(n_samples=500, centers=[(0,0)], cluster_std=0.8)
data2, _ = datasets.make_blobs(n_samples=500, centers=[(4,0)], cluster_std=0.6)
data3, _ = datasets.make_blobs(n_samples=500, centers=[(4,4)], cluster_std=0.4)
data4, _ = datasets.make_blobs(n_samples=500, centers=[(0,4)], cluster_std=0.2)


data = np.vstack([data1,data2,data3,data4])

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()

# %%
data1, _ = datasets.make_blobs(n_samples=500, centers=[(0,0)], cluster_std=0.1)
data2, _ = datasets.make_blobs(n_samples=500, centers=[(10,10)], cluster_std=0.2)
data3, _ = datasets.make_blobs(n_samples=500, centers=[(20,20)], cluster_std=0.4)
data4, _ = datasets.make_blobs(n_samples=500, centers=[(40,40)], cluster_std=0.8)
data5, _ = datasets.make_blobs(n_samples=500, centers=[(60,60)], cluster_std=1.6)
data6, _ = datasets.make_blobs(n_samples=500, centers=[(80,80)], cluster_std=3.2)
data7, _ = datasets.make_blobs(n_samples=500, centers=[(100,100)], cluster_std=6.4)
data8, _ = datasets.make_blobs(n_samples=500, centers=[(120,120640)], cluster_std=12.8)

data = np.vstack([data1,data2,data3,data4,data5,data6,data7,data8])

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()

# %% [markdown]
# # 3. Moon shaped clusters

# %%
data, _ = datasets.make_moons(n_samples=2000, noise=0.15)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()

# %%
data, _ = datasets.make_moons(n_samples=2000, noise=0.05)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()

# %% [markdown]
# # 4. Line

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (1,0),
    (2,0),
    (3,0)
], cluster_std=0.1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (1,0),
    (2,0),
    (3,0)
], cluster_std=0.2)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (0,1),
    (0,2),
    (0,3)
], cluster_std=0.1)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %%
data, _ = datasets.make_blobs(n_samples=2000, centers=[
    (0,0),
    (0,1),
    (0,2),
    (0,3)
], cluster_std=0.2)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # 5.

# %%
X, y = datasets.make_blobs(n_samples=1000, centers=[(0,0)])
X2, y = datasets.make_blobs(n_samples=1000, centers=[(8,8)])

data = np.vstack([X,X2])

# Anisotropicly distributed data
transformation = [[1, 1], [1, 5]]
data = np.dot(data, transformation)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)

# %%
## n_samples = 2000
random_state = 170
X,_ = datasets.make_blobs(n_samples=n_samples, random_state=random_state)

# Anisotropicly distributed data
transformation = [[0.1, 0.1], [0.1, 0.5]]
data = np.dot(X, transformation)

plt.scatter(data.T[0], data.T[1], c='b', **plot_kwds)
frame = plt.gca()
# frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)
